# %% [markdown]
# ### 1. Test Gemini Key

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from google import genai 

project_root = Path.cwd().parent if Path.cwd().name == "Notebooks" else Path.cwd()
load_dotenv(dotenv_path=project_root / ".env")

client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = client.models.generate_content(
    model="gemini-3-flash-preview", 
    contents="Say 'Gemini API working!'"
)
print(response.text)
# Out:
# At its simplest, **Artificial Intelligence (AI)** is the ability of a computer or a robot to perform tasks that usually require human intelligence.
#
# While a traditional computer program follows a strict list of "if-then" instructions, AI is designed to **learn, adapt, and make decisions** based on data.
#
# Here is a breakdown of how it works, the different types, and how we use it today:
#
# ---
#
# ### 1. How does it work?
# Most modern AI is powered by **Machine Learning**. Instead of a human programmer writing a rule for every possible scenario, the AI is fed massive amounts of data. It looks for patterns in that data to "train" itself.
#
# *   **Example:** To teach an AI to recognize a cat, you don't describe what a cat looks like. You show it 10 million pictures of cats. Eventually, the AI identifies the mathematical patterns that define a "cat" and can recognize one it has never seen before.
#
# ### 2. The Two Main Types of AI
# Experts generally divide AI into two categories:
#
# *   **Narrow AI (Weak AI):** This is the AI we have today. It is designed to perform a specific task—like checking the weather, playing chess, or generating text. It may seem brilliant, but it doesn't "know" what it’s doing; it’s just following complex patterns.
# *   **General AI (Strong AI/AGI):** This is a hypothetical AI that would have the ability to understand, learn, and apply intelligence across any task, just like a human. **This does not exist yet** and is currently the subject of science fiction and high-level research.
#
# ### 3. Everyday Examples of AI
# You likely interact with AI dozens of times a day without realizing it:
# *   **Generative AI:** Tools like **ChatGPT** or Claude that can write essays, code, and have conversations.
# *   **Recommendation Engines:** How Netflix knows what movie you’ll like or how Amazon suggests products.
# *   **Virtual Assistants:** Siri, Alexa, and Google Assistant.
# *   **Navigation:** Google Maps using real-time traffic data to predict your arrival time.
# *   **Facial Recognition:** How your phone unlocks by looking at your face.
#
# ### 4. Why is it so popular right now?
# AI has been researched since the 1950s, but it has exploded recently for three reasons:
# 1.  **Massive Data:** The internet provides the "food" AI needs to learn.
# 2.  **Powerful Hardware:** Modern computer chips (GPUs) are now fast enough to process that data.
# 3.  **Better Algorithms:** Scientists have created "Neural Networks" that mimic the way neurons in the human brain work.
#
# ### 5. Why do people worry about it?
# Because AI is becoming so capable, it raises important questions:
# *   **Jobs:** Will AI replace human workers in certain fields?
# *   **Bias:** If an AI is trained on biased data, it will make biased (unfair) decisions.
# *   **Safety:** How do we ensure that highly advanced AI always acts in humanity's best interest?
#
# ### Summary
# Think of AI as a **"prediction engine."** It takes what it has learned from the past to predict what the most helpful or logical next step should be—whether that’s the next word in a sentence, the next turn on a map, or identifying a disease in an X-ray.
